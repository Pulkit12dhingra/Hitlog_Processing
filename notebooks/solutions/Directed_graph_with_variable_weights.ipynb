# %%
# Building on Directed Graph with Frozen weights, This solution adds variablity to the weighs based on their impact for the user registeration

# %%
# data reading
import pandas as pd

df = pd.read_csv("../../data/logs/hitlog_2025-10-27.csv")
df.head()
# Out:
#                                           page_name  \
# 0        Tech | Scientists map deep-sea coral reefs
# 1        Tech | Scientists map deep-sea coral reefs
# 2  Science | Protein-rich lunches you can make fast
# 3   World | Winners and losers from the tax changes
# 4   Lifestyle | Mortgage rates fall for third month
#
#                                             page_url user_id  \
# 0      /articles/scientists-map-deep-sea-coral-reefs    u001
# 1      /articles/scientists-map-deep-sea-coral-reefs    u001
# 2   /articles/protein-rich-lunches-you-can-make-fast    u001
# 3  /articles/winners-and-losers-from-the-tax-changes    u001
# 4      /articles/mortgage-rates-fall-for-third-month    u001
#
#              timestamp
# 0  2025-10-26 16:02:57
# 1  2025-10-26 16:03:55
# 2  2025-10-26 16:06:26
# 3  2025-10-26 16:09:47
# 4  2025-10-26 16:11:04

# %%
# Basic normalization / safety: strip whitespace, coerce timestamp
for col in ["page_name", "page_url", "user_id"]:
    if col in df.columns:
        df[col] = df[col].astype(str).str.strip()
if "timestamp" in df.columns:
    df["timestamp"] = pd.to_datetime(df["timestamp"], errors="coerce")

# Drop rows without a user_id or timestamp (cannot order)
df = df.dropna(subset=["user_id", "timestamp"]).copy()

# %%
# Normalize ordering
df["timestamp"] = pd.to_datetime(df["timestamp"], utc=True)
df = df.sort_values(["user_id", "timestamp"], kind="mergesort").reset_index(drop=True)
df.head()
# Out:
#                                           page_name  \
# 0        Tech | Scientists map deep-sea coral reefs
# 1        Tech | Scientists map deep-sea coral reefs
# 2  Science | Protein-rich lunches you can make fast
# 3   World | Winners and losers from the tax changes
# 4   Lifestyle | Mortgage rates fall for third month
#
#                                             page_url user_id  \
# 0      /articles/scientists-map-deep-sea-coral-reefs    u001
# 1      /articles/scientists-map-deep-sea-coral-reefs    u001
# 2   /articles/protein-rich-lunches-you-can-make-fast    u001
# 3  /articles/winners-and-losers-from-the-tax-changes    u001
# 4      /articles/mortgage-rates-fall-for-third-month    u001
#
#                   timestamp
# 0 2025-10-26 16:02:57+00:00
# 1 2025-10-26 16:03:55+00:00
# 2 2025-10-26 16:06:26+00:00
# 3 2025-10-26 16:09:47+00:00
# 4 2025-10-26 16:11:04+00:00

# %%
# Constants
REG_URL = "/register"
ARTICLE_PREFIX = "/articles/"

# Keep only article and registration events (graph stays focused)
df = df[
    df["page_url"].str.startswith(ARTICLE_PREFIX) | (df["page_url"] == REG_URL)
].copy()

df.head()
# Out:
#                                           page_name  \
# 0        Tech | Scientists map deep-sea coral reefs
# 1        Tech | Scientists map deep-sea coral reefs
# 2  Science | Protein-rich lunches you can make fast
# 3   World | Winners and losers from the tax changes
# 4   Lifestyle | Mortgage rates fall for third month
#
#                                             page_url user_id  \
# 0      /articles/scientists-map-deep-sea-coral-reefs    u001
# 1      /articles/scientists-map-deep-sea-coral-reefs    u001
# 2   /articles/protein-rich-lunches-you-can-make-fast    u001
# 3  /articles/winners-and-losers-from-the-tax-changes    u001
# 4      /articles/mortgage-rates-fall-for-third-month    u001
#
#                   timestamp
# 0 2025-10-26 16:02:57+00:00
# 1 2025-10-26 16:03:55+00:00
# 2 2025-10-26 16:06:26+00:00
# 3 2025-10-26 16:09:47+00:00
# 4 2025-10-26 16:11:04+00:00

# %%
DECAY = (
    0.85  # Per-step decay as we move backward from /register (closer pages matter more)
)
BASE_HIT = 1.0  # Base contribution for each article occurrence
LANDING_BONUS = 0.5  # Extra credit for the first article in the journey (the attractor)


# - Increase DECAY (closer to 1.0) to give more credit to earlier pages in the journey.
# - Decrease DECAY (closer to 0.5) to focus influence on pages right before /register.
# - Increase LANDING_BONUS to reward pages that likely "attracted" the user to the journey.
# - Increase BASE_HIT if you want repeated exposures within a journey to matter more (they stack).

# %%
class Node:
    def __init__(self, url: str, name: str):
        self.url = url
        self.name = name
        self.neighbors = (
            set()
        )  # directed edges to next visited page (for reference/inspection)
        self.weight = 0.0  # accumulated influence score across all journeys

# %%
# Global registry: one Node per unique page_url (including /register for edges)
nodes = {}

# %%
# Ensure a node exists for every seen page
for _, row in df.iterrows():
    url = row["page_url"]
    name = row["page_name"]
    if url not in nodes:
        nodes[url] = Node(url, name)

# Add edges
for user_id, grp in df.groupby("user_id", sort=False):
    prev = None
    for _, row in grp.iterrows():
        cur = nodes[row["page_url"]]
        if prev is not None:
            prev.neighbors.add(cur)
        prev = cur

# %%
# Journey traversal with decay ranking
for user_id, grp in df.groupby("user_id", sort=False):
    # Collect article URLs for the current journey
    journey_urls = []  # ordered list of article page_urls since last /register
    journey_names = []  # aligned page_name list

    for _, row in grp.iterrows():
        url = row["page_url"]
        name = row["page_name"]

        if url.startswith(ARTICLE_PREFIX):
            # Accumulate this occurrence; duplicates are allowed and will stack weight later
            journey_urls.append(url)
            journey_names.append(name)

        if url == REG_URL:
            # We reached a registration => distribute influence back along the journey
            if journey_urls:
                # 1) Landing bonus to the *first* article of the journey (the attractor)
                #    That is the *first* element in journey_urls
                first_url = journey_urls[0]
                nodes[first_url].weight += LANDING_BONUS

                # 2) Now traverse backwards from /register through the journey.
                #    pos_from_end = 0 for the closest page before /register, then 1, 2, ...
                #    contribution = BASE_HIT * (DECAY ** pos_from_end)
                #    If a page appears multiple times, it accumulates contributions each time.
                for pos_from_end, url_back in enumerate(reversed(journey_urls)):
                    contrib = BASE_HIT * (DECAY**pos_from_end)
                    nodes[url_back].weight += contrib

            # Reset for the next journey
            journey_urls.clear()
            journey_names.clear()

# %%
# Build result table
records = []
for node in nodes.values():
    if node.url.startswith(ARTICLE_PREFIX) and node.weight > 0:
        records.append(
            {
                "page_name": node.name,
                "page_url": node.url,
                "total_weight": round(node.weight, 6),
            }
        )

result = (
    pd.DataFrame(records, columns=["page_name", "page_url", "total_weight"])
    .sort_values(
        ["total_weight", "page_url"], ascending=[False, True], kind="mergesort"
    )
    .reset_index(drop=True)
)


print("\nTop 10 pages by influence (with decay):")
result.head(50)
# Out:
# Top 10 pages by influence (with decay):
#                                             page_name  \
# 0                Science | How to back up your photos
# 1     World | Winners and losers from the tax changes
# 2          Tech | Scientists map deep-sea coral reefs
# 3              Lifestyle | The best hikes near London
# 4               Sport | What next for interest rates?
# 5    Science | Protein-rich lunches you can make fast
# 6      Culture | Volcano eruption prompts evacuations
# 7          Travel | Investor guide to dividend stocks
# 8     Tech | Championship title race down to the wire
# 9   Tech | New smartphone chips promise longer bat...
# 10    Lifestyle | Mortgage rates fall for third month
# 11            Sport | Gardeners’ tips for late blooms
# 12  Lifestyle | Major airline plans new transatlan...
# 13    Travel | University rankings shake-up explained
# 14   Tech | UK house prices show signs of stabilising
# 15      Health | Breakthrough in clean energy storage
# 16           Sport | Markets rally as inflation cools
# 17            World | Rugby World Cup tactical trends
# 18     Sport | Electric cars: charging myths debunked
# 19        Culture | Top museums to visit this weekend
# 20          World | Five habits linked to longer life
# 21                Health | The future of home working
# 22   Tech | Flu season: What doctors want you to know
# 23         World | Art exhibition draws record crowds
# 24  Business | The ultimate guide to marathon tape...
# 25    Politics | What the new data rules mean for you
# 26        Travel | Hidden gems for autumn city breaks
# 27            World | Inside the race to build fusion
# 28              World | Recipe: One-pan roast chicken
# 29      Politics | AI start-ups race to raise funding
# 30         Politics | Europe braces for winter storms
# 31  Culture | Start-up founders on surviving downt...
# 32       Business | Inside a pioneering vertical farm
#
#                                              page_url  total_weight
# 0                /articles/how-to-back-up-your-photos      4.526799
# 1   /articles/winners-and-losers-from-the-tax-changes      4.411103
# 2       /articles/scientists-map-deep-sea-coral-reefs      3.490890
# 3                /articles/the-best-hikes-near-london      3.161852
# 4              /articles/what-next-for-interest-rates      3.020577
# 5    /articles/protein-rich-lunches-you-can-make-fast      2.900414
# 6      /articles/volcano-eruption-prompts-evacuations      2.760411
# 7         /articles/investor-guide-to-dividend-stocks      2.572500
# 8   /articles/championship-title-race-down-to-the-...      1.892616
# 9   /articles/new-smartphone-chips-promise-longer-...      1.726607
# 10      /articles/mortgage-rates-fall-for-third-month      1.554754
# 11          /articles/gardeners--tips-for-late-blooms      1.544013
# 12  /articles/major-airline-plans-new-transatlanti...      1.244506
# 13   /articles/university-rankings-shake-up-explained      1.136131
# 14  /articles/uk-house-prices-show-signs-of-stabil...      1.057830
# 15     /articles/breakthrough-in-clean-energy-storage      1.000000
# 16         /articles/markets-rally-as-inflation-cools      1.000000
# 17          /articles/rugby-world-cup-tactical-trends      1.000000
# 18   /articles/electric-cars--charging-myths-debunked      0.991275
# 19        /articles/top-museums-to-visit-this-weekend      0.988686
# 20        /articles/five-habits-linked-to-longer-life      0.943705
# 21               /articles/the-future-of-home-working      0.850000
# 22  /articles/flu-season--what-doctors-want-you-to...      0.745011
# 23       /articles/art-exhibition-draws-record-crowds      0.722500
# 24  /articles/the-ultimate-guide-to-marathon-tapering      0.722500
# 25     /articles/what-the-new-data-rules-mean-for-you      0.722500
# 26       /articles/hidden-gems-for-autumn-city-breaks      0.642912
# 27          /articles/inside-the-race-to-build-fusion      0.614125
# 28            /articles/recipe--one-pan-roast-chicken      0.614125
# 29       /articles/ai-start-ups-race-to-raise-funding      0.522006
# 30          /articles/europe-braces-for-winter-storms      0.522006
# 31  /articles/start-up-founders-on-surviving-downt...      0.377150
# 32        /articles/inside-a-pioneering-vertical-farm      0.196874
