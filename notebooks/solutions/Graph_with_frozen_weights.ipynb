# %%
# This Notebook presents Graph based solution with frozen weights to 1

# %%
# data reading
import pandas as pd

df = pd.read_csv("../../data/logs/hitlog_2025-10-27.csv")
df.head()
# Out:
#                                           page_name  \
# 0        Tech | Scientists map deep-sea coral reefs
# 1        Tech | Scientists map deep-sea coral reefs
# 2  Science | Protein-rich lunches you can make fast
# 3   World | Winners and losers from the tax changes
# 4   Lifestyle | Mortgage rates fall for third month
#
#                                             page_url user_id  \
# 0      /articles/scientists-map-deep-sea-coral-reefs    u001
# 1      /articles/scientists-map-deep-sea-coral-reefs    u001
# 2   /articles/protein-rich-lunches-you-can-make-fast    u001
# 3  /articles/winners-and-losers-from-the-tax-changes    u001
# 4      /articles/mortgage-rates-fall-for-third-month    u001
#
#              timestamp
# 0  2025-10-26 16:02:57
# 1  2025-10-26 16:03:55
# 2  2025-10-26 16:06:26
# 3  2025-10-26 16:09:47
# 4  2025-10-26 16:11:04

# %%
# Basic normalization / safety: strip whitespace, coerce timestamp
for col in ["page_name", "page_url", "user_id"]:
    if col in df.columns:
        df[col] = df[col].astype(str).str.strip()
if "timestamp" in df.columns:
    df["timestamp"] = pd.to_datetime(df["timestamp"], errors="coerce")

# Drop rows without a user_id or timestamp (cannot order)
df = df.dropna(subset=["user_id", "timestamp"]).copy()

# %%
# Normalize ordering
df["timestamp"] = pd.to_datetime(df["timestamp"], utc=True)
df = df.sort_values(["user_id", "timestamp"], kind="mergesort").reset_index(drop=True)
df.head()
# Out:
#                                           page_name  \
# 0        Tech | Scientists map deep-sea coral reefs
# 1        Tech | Scientists map deep-sea coral reefs
# 2  Science | Protein-rich lunches you can make fast
# 3   World | Winners and losers from the tax changes
# 4   Lifestyle | Mortgage rates fall for third month
#
#                                             page_url user_id  \
# 0      /articles/scientists-map-deep-sea-coral-reefs    u001
# 1      /articles/scientists-map-deep-sea-coral-reefs    u001
# 2   /articles/protein-rich-lunches-you-can-make-fast    u001
# 3  /articles/winners-and-losers-from-the-tax-changes    u001
# 4      /articles/mortgage-rates-fall-for-third-month    u001
#
#                   timestamp
# 0 2025-10-26 16:02:57+00:00
# 1 2025-10-26 16:03:55+00:00
# 2 2025-10-26 16:06:26+00:00
# 3 2025-10-26 16:09:47+00:00
# 4 2025-10-26 16:11:04+00:00

# %%
# Constants
REG_URL = "/register"
ARTICLE_PREFIX = "/articles/"

# Keep only article and registration events (graph stays focused)
df = df[
    df["page_url"].str.startswith(ARTICLE_PREFIX) | (df["page_url"] == REG_URL)
].copy()

df.head()
# Out:
#                                           page_name  \
# 0        Tech | Scientists map deep-sea coral reefs
# 1        Tech | Scientists map deep-sea coral reefs
# 2  Science | Protein-rich lunches you can make fast
# 3   World | Winners and losers from the tax changes
# 4   Lifestyle | Mortgage rates fall for third month
#
#                                             page_url user_id  \
# 0      /articles/scientists-map-deep-sea-coral-reefs    u001
# 1      /articles/scientists-map-deep-sea-coral-reefs    u001
# 2   /articles/protein-rich-lunches-you-can-make-fast    u001
# 3  /articles/winners-and-losers-from-the-tax-changes    u001
# 4      /articles/mortgage-rates-fall-for-third-month    u001
#
#                   timestamp
# 0 2025-10-26 16:02:57+00:00
# 1 2025-10-26 16:03:55+00:00
# 2 2025-10-26 16:06:26+00:00
# 3 2025-10-26 16:09:47+00:00
# 4 2025-10-26 16:11:04+00:00

# %%
# Graph Node definition
class Node:
    def __init__(self, url: str, name: str):
        self.url = url  # page_url
        self.name = name  # page_name (assumed stable for the URL)
        self.neighbors = set()  # set of Node (directed edges to next visited pages)
        self.weight = 0  # accumulated influence count across all journeys

# %%
# Global node registry: url -> Node
nodes = {}

# %%
# Build graph structure (unique user_id → path edges between consecutive nodes)
# Also ensure a Node exists for every encountered page.

for _, row in df.iterrows():
    url = row["page_url"]
    name = row["page_name"]
    if url not in nodes:
        nodes[url] = Node(url, name)

# Create directed edges based on each user's chronological sequence
for user_id, grp in df.groupby("user_id", sort=False):
    prev_node = None
    for _, row in grp.iterrows():
        cur = nodes[row["page_url"]]
        if prev_node is not None:
            prev_node.neighbors.add(cur)
        prev_node = cur

# %%
# Traverse the graph per user timeline and apply journey logic
# - Iterate the *ordered events* for each user (this preserves the real navigation order).
# - "freeze" an article node for the current journey once seen (so repeated hits don't add more).
# - On hitting /register, we commit +1 to each seen-article node's global weight.

for user_id, grp in df.groupby("user_id", sort=False):
    # Tracks which article URLs have been seen in the CURRENT journey (frozen set)
    seen_in_journey = set()

    for _, row in grp.iterrows():
        url = row["page_url"]

        # If it's an article and not yet frozen in this journey, freeze it (+1 *pending* for this journey)
        if url.startswith(ARTICLE_PREFIX) and url not in seen_in_journey:
            seen_in_journey.add(url)

        # If we reached a registration, COMMIT +1 for all frozen article nodes in this journey, then reset
        if url == REG_URL:
            for art_url in seen_in_journey:
                nodes[art_url].weight += 1
            seen_in_journey.clear()  # unfreeze for the next journey

# %%
# Build the output DataFrame from node weights
# Only include article nodes with weight > 0 (influential)

records = []
for n in nodes.values():
    if n.url.startswith(ARTICLE_PREFIX) and n.weight > 0:
        records.append({"page_name": n.name, "page_url": n.url, "total": int(n.weight)})

result = (
    pd.DataFrame(records, columns=["page_name", "page_url", "total"])
    .sort_values(["total", "page_url"], ascending=[False, True], kind="mergesort")
    .reset_index(drop=True)
)

print("\nTop 10 influential articles (graph-based):")
result.head(40)
# Out:
# Top 10 influential articles (graph-based):
#                                             page_name  \
# 0     World | Winners and losers from the tax changes
# 1     Tech | Championship title race down to the wire
# 2                Science | How to back up your photos
# 3     Lifestyle | Mortgage rates fall for third month
# 4    Science | Protein-rich lunches you can make fast
# 5          Tech | Scientists map deep-sea coral reefs
# 6      Culture | Volcano eruption prompts evacuations
# 7               Sport | What next for interest rates?
# 8      Sport | Electric cars: charging myths debunked
# 9             Sport | Gardeners’ tips for late blooms
# 10        Travel | Hidden gems for autumn city breaks
# 11         Travel | Investor guide to dividend stocks
# 12        Culture | Top museums to visit this weekend
# 13   Tech | UK house prices show signs of stabilising
# 14    Travel | University rankings shake-up explained
# 15      Politics | AI start-ups race to raise funding
# 16         World | Art exhibition draws record crowds
# 17      Health | Breakthrough in clean energy storage
# 18         Politics | Europe braces for winter storms
# 19          World | Five habits linked to longer life
# 20   Tech | Flu season: What doctors want you to know
# 21       Business | Inside a pioneering vertical farm
# 22            World | Inside the race to build fusion
# 23  Lifestyle | Major airline plans new transatlan...
# 24           Sport | Markets rally as inflation cools
# 25  Tech | New smartphone chips promise longer bat...
# 26              World | Recipe: One-pan roast chicken
# 27            World | Rugby World Cup tactical trends
# 28  Culture | Start-up founders on surviving downt...
# 29             Lifestyle | The best hikes near London
# 30                Health | The future of home working
# 31  Business | The ultimate guide to marathon tape...
# 32    Politics | What the new data rules mean for you
#
#                                              page_url  total
# 0   /articles/winners-and-losers-from-the-tax-changes      5
# 1   /articles/championship-title-race-down-to-the-...      4
# 2                /articles/how-to-back-up-your-photos      3
# 3       /articles/mortgage-rates-fall-for-third-month      3
# 4    /articles/protein-rich-lunches-you-can-make-fast      3
# 5       /articles/scientists-map-deep-sea-coral-reefs      3
# 6      /articles/volcano-eruption-prompts-evacuations      3
# 7              /articles/what-next-for-interest-rates      3
# 8    /articles/electric-cars--charging-myths-debunked      2
# 9           /articles/gardeners--tips-for-late-blooms      2
# 10       /articles/hidden-gems-for-autumn-city-breaks      2
# 11        /articles/investor-guide-to-dividend-stocks      2
# 12        /articles/top-museums-to-visit-this-weekend      2
# 13  /articles/uk-house-prices-show-signs-of-stabil...      2
# 14   /articles/university-rankings-shake-up-explained      2
# 15       /articles/ai-start-ups-race-to-raise-funding      1
# 16       /articles/art-exhibition-draws-record-crowds      1
# 17     /articles/breakthrough-in-clean-energy-storage      1
# 18          /articles/europe-braces-for-winter-storms      1
# 19        /articles/five-habits-linked-to-longer-life      1
# 20  /articles/flu-season--what-doctors-want-you-to...      1
# 21        /articles/inside-a-pioneering-vertical-farm      1
# 22          /articles/inside-the-race-to-build-fusion      1
# 23  /articles/major-airline-plans-new-transatlanti...      1
# 24         /articles/markets-rally-as-inflation-cools      1
# 25  /articles/new-smartphone-chips-promise-longer-...      1
# 26            /articles/recipe--one-pan-roast-chicken      1
# 27          /articles/rugby-world-cup-tactical-trends      1
# 28  /articles/start-up-founders-on-surviving-downt...      1
# 29               /articles/the-best-hikes-near-london      1
# 30               /articles/the-future-of-home-working      1
# 31  /articles/the-ultimate-guide-to-marathon-tapering      1
# 32     /articles/what-the-new-data-rules-mean-for-you      1
